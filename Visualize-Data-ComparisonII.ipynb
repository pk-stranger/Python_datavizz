# %%
import pandas as pd

# %%
from matplotlib import pyplot as plt     # หรือ import matplotlib.pyplot as plt ก็ได้เช่นกัน

# %%
df = pd.read_excel('D:\\basicdata\\income.xls', header = 3)
df
# Out:
#           ภาค และจังหวัด                                         Unnamed: 1  \
# 0                    NaN                                                NaN
# 1                    NaN                                                NaN
# 2        ทั่วราชอาณาจักร                                                NaN
# 3               ตอนพิเศษ                                                NaN
# 4          กรุงเทพมหานคร                                                NaN
# ..                   ...                                                ...
# 84              นราธิวาส                                                NaN
# 85                   NaN                                                NaN
# 86                   NaN                                                NaN
# 87                ที่มา:  การสำรวจภาวะเศรษฐกิจและสังคมของครัวเรือน  สำนั...
# 88               Source:  The Household Socio - Economic Survey, Nationa...
#
#         2541      2543      2545      2547      2549      2550      2552  \
# 0     1998.0    2000.0    2002.0    2004.0    2006.0    2007.0    2009.0
# 1        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 2    69674.0   68405.0   82485.0  104571.0  116585.0  116681.0  134699.3
# 3   131740.0  126527.0  157730.0  155622.0  155212.0  151168.0  199608.1
# 4   138247.0  135137.0  162199.0  160776.0  158059.0  155396.0  207665.0
# ..       ...       ...       ...       ...       ...       ...       ...
# 84   25071.0   15087.0   34023.0   39297.0   57235.0   36368.0   26246.4
# 85       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 86       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 87       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 88       NaN       NaN       NaN       NaN       NaN       NaN       NaN
#
#         2554      2556           2558    Region and province
# 0     2011.0    2013.0    2015.000000                    NaN
# 1        NaN       NaN            NaN                    NaN
# 2   134899.9  163087.0  156770.455510          Whole Kingdom
# 3   202157.2  273795.0  171837.386694        Greater Bangkok
# 4   218741.4  275576.8  164705.600000                Bangkok
# ..       ...       ...            ...                    ...
# 84   40942.5   44974.1   40566.900000             Narathiwat
# 85       NaN       NaN            NaN                    NaN
# 86       NaN       NaN            NaN                    NaN
# 87       NaN       NaN            NaN                    NaN
# 88       NaN       NaN            NaN                    NaN
#
# [89 rows x 13 columns]

# %%
# เอาแค่ กรุงเทพ สมุทรปราการ นนทบุรี และปทุมธานี ซึ่งเป็นข้อมูลที่เราต้องการ
greaterbangkok = df.iloc[4:8,:]
greaterbangkok
# Out:
#          ภาค และจังหวัด Unnamed: 1      2541      2543      2545      2547  \
# 4         กรุงเทพมหานคร        NaN  138247.0  135137.0  162199.0  160776.0
# 5           สมุทรปราการ        NaN   40632.0   67390.0   84345.0   78750.0
# 6               นนทบุรี        NaN  112337.0  102994.0  145908.0  203040.0
# 7              ปทุมธานี        NaN  217932.0  139691.0  232245.0  145015.0
#
#        2549      2550      2552      2554      2556      2558  \
# 4  158059.0  155396.0  207665.0  218741.4  275576.8  164705.6
# 5   95975.0   85904.0  117360.8  115168.8  207741.1   87647.2
# 6  179007.0  196895.0  240769.0  258853.4  260752.2  277605.7
# 7  193153.0  152187.0  220761.2  145293.0  386957.4  221748.2
#
#        Region and province
# 4                  Bangkok
# 5             Samut Prakan
# 6               Nonthaburi
# 7             Pathum Thani

# %% [markdown]
# # Barchart = กราฟแท่ง

# %% [markdown]
# ### สร้างกราฟแท่งเปรียบเทียบรายได้ในปี 2541 ของจังหวัดกรุงเทพ และปริมณฑล

# %%
plt.bar([1, 2, 3, 4], greaterbangkok.iloc[:,2])      # มีทั้งหมด 4 กราฟ จึงเป็น 1, 2, 3, 4 เป็นกราฟของจังหวัดกรุงเทพ สมุทรปราการ นนทบุรี และปทุมธานี
plt.title('Barchart comparing incomes of provinces in Greater Bangkok in 2541');

# %%
plt.bar([1, 2, 3, 4], greaterbangkok.iloc[:,2])
plt.title('Barchart comparing incomes of provinces in Greater Bangkok in 2541')
plt.xlabel('Provinces')
plt.ylabel('Income Baht/Month/Household');

# %% [markdown]
# ## add tick label

# %%
plt.bar([1, 2, 3, 4], greaterbangkok.iloc[:,2], tick_label = ['Bangkok', 'Samut Prakan', 'Nonthaburi', 'Pathum Thani'])
plt.title('Barchart comparing incomes of provinces in Greater Bangkok in 2541')
plt.xlabel('Provinces')
plt.ylabel('Income Baht/Month/Household');

# %% [markdown]
# ## หรือทำแบบคนฉลาดมีความรู้ โดยใช้ iloc

# %%
plt.bar([1, 2, 3, 4], greaterbangkok.iloc[:,2], tick_label = greaterbangkok.iloc[:,-1])
plt.title('Barchart comparing incomes of provinces in Greater Bangkok in 2541')
plt.xlabel('Provinces')
plt.ylabel('Income Baht/Month/Household');

# %% [markdown]
# ## Compare different years

# %%
plt.bar([1-(0.35/2), 2-(0.35/2), 3-(0.35/2), 4-(0.35/2)], greaterbangkok.iloc[:,-2], width=0.35, tick_label = greaterbangkok.iloc[:,-1], color = 'm', label = '2558')
plt.bar([1+(0.35/2), 2+(0.35/2), 3+(0.35/2), 4+(0.35/2)], greaterbangkok.iloc[:,2], width=0.35, tick_label = greaterbangkok.iloc[:,-1], color = 'c', label = '2541');

# %%
plt.bar([1-(0.35/2), 2-(0.35/2), 3-(0.35/2), 4-(0.35/2)], greaterbangkok.iloc[:,-2], width=0.35, tick_label = greaterbangkok.iloc[:,-1], color = 'm', label = '2558', align='edge')
plt.bar([1+(0.35/2), 2+(0.35/2), 3+(0.35/2), 4+(0.35/2)], greaterbangkok.iloc[:,2], width=0.35, tick_label = greaterbangkok.iloc[:,-1], color = 'c', label = '2541', align='edge');

# %%
plt.bar([1-(0.35/2), 2-(0.35/2), 3-(0.35/2), 4-(0.35/2)], greaterbangkok.iloc[:,-2], width=0.35, tick_label = greaterbangkok.iloc[:,-1], color = 'm', label = '2558', align='edge')
plt.bar([1+(0.35/2), 2+(0.35/2), 3+(0.35/2), 4+(0.35/2)], greaterbangkok.iloc[:,2], width=0.35, tick_label = greaterbangkok.iloc[:,-1], color = 'c', label = '2541', align='edge')
plt.title('Barchart comparing incomes of provinces in Greater Bangkok in 2541')
plt.xlabel('Provinces')
plt.ylabel('Income Baht/Month/Household');

# %%
plt.bar([1-(0.35/2), 2-(0.35/2), 3-(0.35/2), 4-(0.35/2)], greaterbangkok.iloc[:,-2], width=0.35, tick_label = greaterbangkok.iloc[:,-1], color = 'm', label = '2558', align='edge')
plt.bar([1+(0.35/2), 2+(0.35/2), 3+(0.35/2), 4+(0.35/2)], greaterbangkok.iloc[:,2], width=0.35, tick_label = greaterbangkok.iloc[:,-1], color = 'c', label = '2541', align='edge')
plt.title('Barchart comparing incomes of provinces in Greater Bangkok in 2541')
plt.xlabel('Provinces')
plt.legend()
plt.ylabel('Income Baht/Month/Household');

# %% [markdown]
# # Stacked Barchart

# %%
saledata = pd.DataFrame([{'North':20, 'East':10, 'West':90, 'South':120},
                                    {'North':220, 'East':20, 'West':50, 'South':90}])
saledata
# Out:
#    North  East  West  South
# 0     20    10    90    120
# 1    220    20    50     90

# %%
plt.bar([1, 2], saledata.iloc[:,0], tick_label =['Company A','Company B'])
plt.bar([1, 2], saledata.iloc[:,1], bottom = saledata.iloc[:,0], tick_label = ['Company A','Company B']);

# %%
plt.bar([1, 2], saledata.iloc[:,0], tick_label =['Company A','Company B'])
plt.bar([1, 2], saledata.iloc[:,1], bottom = saledata.iloc[:,0], tick_label = ['Company A','Company B'])
plt.bar([1, 2], saledata.iloc[:,2], bottom = saledata.iloc[:,0], tick_label = ['Company A','Company B']);

# %%
plt.bar([1, 2], saledata.iloc[:,0], tick_label =['Company A','Company B'])
plt.bar([1, 2], saledata.iloc[:,1], bottom = saledata.iloc[:,0], tick_label = ['Company A','Company B'])
plt.bar([1, 2], saledata.iloc[:,2], bottom = saledata.iloc[:,0]+saledata.iloc[:,1], tick_label = ['Company A','Company B'])
plt.bar([1, 2], saledata.iloc[:,3], bottom = saledata.iloc[:,0]+saledata.iloc[:,1]+saledata.iloc[:,2], tick_label = ['Company A','Company B']);

# %% [markdown]
# # Histogram

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Fixing random state for reproducibility
np.random.seed(19680801)

# %%
np.random.randn()
# Out:
# 1.0493043103878812

# %%
mu, sigma = 100,15
x =mu + sigma*np.random.randn(10000)

# %%
x
# Out:
# array([112.99148762, 108.267019  , 125.92116686, ...,  73.28843349,
#         77.0735325 , 107.25414148])

# %%
plt.hist(x, 50, density=True, facecolor = 'r', alpha=0.75); #มีตัวเลขเยอะๆ อยากรู้ว่าตัวเลขในมีเยอะที่สุด ก็คือเลข 0.025

# %% [markdown]
# # Treemap

# %%
import numpy as np
import matplotlib.pyplot as plt
import squarify

# %%
volume = [350, 220, 170, 150, 50]

# %%
squarify.plot(sizes=volume)

# %%
labels = ['Liquid\n volume: 350k', 'Savoury\n volume: 220k',
          'Sugar\n volume: 170k', 'Frozen\n volume: 150k',
          'Non-food\n volume: 50k']
color_list = ['#0f7216', '#b2790c', '#ffe9a3',
              '#f9d4d4', '#d35158', '#ea3033']

# %%
squarify.plot(sizes=volume, label=labels,
              color=color_list, alpha=0.5)

# %% [markdown]
# # Radar chart

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from math import pi

# %%
pi #ค่าพาย
# Out:
# 3.141592653589793

# %%
sales_3 = {'client_id': ['c1', 'c2', 'c3','c4'], 
           'cheese': [2,5,4,3], 
           'beer': [2,1,3,5], 
           'chicken': [5,3,3,4],
          'bread':[4,3,2,1],
          'coffee':[2,3,5,3]}
df_3 = pd.DataFrame.from_dict(sales_3)

# %%
df_3
# Out:
#   client_id  cheese  beer  chicken  bread  coffee
# 0        c1       2     2        5      4       2
# 1        c2       5     1        3      3       3
# 2        c3       4     3        3      2       5
# 3        c4       3     5        4      1       3

# %%
categories = list(df_3)[1:]

# %%
categories
# Out:
# ['cheese', 'beer', 'chicken', 'bread', 'coffee']

# %%
values = df_3.mean().values.flatten().tolist()
values += values[:1] # repeat the first value to close the circular graph
angles = [n / float(len(categories)) * 2 * pi for n in range(len(categories))]
angles += angles[:1]

# %%
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(8, 8),
                       subplot_kw=dict(polar=True))

plt.xticks(angles[:-1], categories, color='grey', size=12)
plt.yticks(np.arange(1, 6), ['1', '2', '3', '4', '5'],
           color='grey', size=12)

plt.ylim(0, 5)
ax.set_rlabel_position(30)

ax.plot(angles, values, linewidth=1, linestyle='solid')
ax.fill(angles, values, 'skyblue', alpha=0.4)
#fill คือเติมสีที่เราต้องการ
## การplot ต้องสร้างในเชลเดียวกัน

# %%
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(8, 8),
                       subplot_kw=dict(polar=True))

plt.xticks(angles[:-1], categories, color='grey', size=12)
plt.yticks(np.arange(1, 6), ['1', '2', '3', '4', '5'],
           color='grey', size=12)
# part 1
val_c1 = df_3.loc[0].drop('client_id').values.flatten().tolist()
val_c1 += val_c1[:1]
ax.plot(angles, val_c1, linewidth=1,
        linestyle='solid', label='Client c1')
ax.fill(angles, val_c1, 'skyblue', alpha=0.4)
 
# part 2
val_c2=df_3.loc[1].drop('client_id').values.flatten().tolist()
val_c2 += val_c2[:1]
ax.plot(angles, val_c2, linewidth=1,
        linestyle='solid', label='Client c2')
ax.fill(angles, val_c2, 'lightpink', alpha=0.4)
 
plt.legend(loc='upper right', bbox_to_anchor=(0.1, 0.1))
plt.show()

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from PIL import Image
import numpy as np

# %%
text = ('Data science is an interdisciplinary field that uses scientific \
methods, processes, algorithms and systems to extract knowledge and insights \
from data in various forms, both structured and unstructured, similar to data \
mining. Data science is a concept to unify statistics, data analysis, machine \
learning and their related methods in order to understand and analyze actual \
phenomena with data. It employs techniques and theories drawn from many fields \
within the context of mathematics, statistics, information science, and \
computer science. Turing award winner Jim Gray imagined data science as a \
fourth paradigm of science (empirical, theoretical, computational and now \
data-driven) and asserted that everything about science is changing because of \
the impact of information technology and the data deluge. In 2012, when Harvard \
Business Review called it The Sexiest Job of the 21st Century, the term data \
science became a buzzword. It is now often used interchangeably with earlier \
concepts like business analytics, business intelligence, predictive modeling, \
and statistics. Even the suggestion that data science is sexy was paraphrasing \
Hans Rosling, featured in a 2011 BBC documentary with the quote, Statistics is \
now the sexiest subject around. Nate Silver referred to data science as a sexed \
up term for statistics. In many cases, earlier approaches and solutions are now \
simply rebranded as data science to be more attractive, which can cause the \
term to become dilute beyond usefulness. While many university programs now \
offer a data science degree, there exists no consensus on a definition or \
suitable curriculum contents. To its discredit, however, many data-science and \
big-data projects fail to deliver useful results, often as a result of poor \
management and utilization of resources')

wordcloud = WordCloud(width=1280, height=853, margin=0,
                      colormap='hot').generate(text)

plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.margins(x=0, y=0)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image
from wordcloud import WordCloud

# %%
df_4 = pd.read_csv('D:\\basicdata\\message.csv', header = 3)
df_4
# Out:
#        2  U0322c3e8de4f8a4eac8ec3bbefa21cfb  1582168285  \
# 0      3  U0322c3e8de4f8a4eac8ec3bbefa21cfb  1582168308
# 1      4  U0322c3e8de4f8a4eac8ec3bbefa21cfb  1582168312
# 2      5  U0322c3e8de4f8a4eac8ec3bbefa21cfb  1582168325
# 3      6  U0322c3e8de4f8a4eac8ec3bbefa21cfb  1582168332
# 4      7  U0eda03c8726701deaf36ec904912d79f  1582604224
# ..   ...                                ...         ...
# 960  963  Uf9cb1d388c137ce49307370e6e9120e1  1582631314
# 961  964  Ufd3d31906486863b4dabc0b563c7802a  1582604220
# 962  965  Ufd3d31906486863b4dabc0b563c7802a  1582604226
# 963  966  Ufd3d31906486863b4dabc0b563c7802a  1582604239
# 964  967  Ufd3d31906486863b4dabc0b563c7802a  1582604245
#
#      2020-02-20 03:11:27.726517+00:00           img : Trichuris  \
# 0    2020-02-20 03:11:50.517959+00:00             img : Ascaris
# 1    2020-02-20 03:11:53.716016+00:00                     อาการ
# 2    2020-02-20 03:12:07.268072+00:00           ชนิดของไข่พยาธิ
# 3    2020-02-20 03:12:13.237326+00:00  รู้ได้อย่างไรว่าติดพยาธิ
# 4    2020-02-25 04:17:04.346318+00:00                 หวัดดีจ้า
# ..                                ...                       ...
# 960  2020-02-25 11:48:34.553253+00:00                       บาย
# 961  2020-02-25 04:17:00.036043+00:00                   Dee kub
# 962  2020-02-25 04:17:06.610285+00:00                     ดีคับ
# 963  2020-02-25 04:17:19.324156+00:00                สวัสดีครับ
# 964  2020-02-25 04:17:25.054467+00:00                        Hi
#
#      W/"datetime'2020-02-20T03%3A11%3A27.7265177Z'"
# 0    W/"datetime'2020-02-20T03%3A11%3A50.5179595Z'"
# 1    W/"datetime'2020-02-20T03%3A11%3A53.7160165Z'"
# 2    W/"datetime'2020-02-20T03%3A12%3A07.2680726Z'"
# 3     W/"datetime'2020-02-20T03%3A12%3A13.237326Z'"
# 4    W/"datetime'2020-02-25T04%3A17%3A04.3463183Z'"
# ..                                              ...
# 960  W/"datetime'2020-02-25T11%3A48%3A34.5532534Z'"
# 961  W/"datetime'2020-02-25T04%3A17%3A00.0360436Z'"
# 962  W/"datetime'2020-02-25T04%3A17%3A06.6102857Z'"
# 963   W/"datetime'2020-02-25T04%3A17%3A19.324156Z'"
# 964  W/"datetime'2020-02-25T04%3A17%3A25.0544679Z'"
#
# [965 rows x 6 columns]

# %%
mg = df_4.iloc[:,-2]

# %%
mg
# Out:
# 0                 img : Ascaris
# 1                         อาการ
# 2               ชนิดของไข่พยาธิ
# 3      รู้ได้อย่างไรว่าติดพยาธิ
# 4                     หวัดดีจ้า
#                  ...
# 960                         บาย
# 961                     Dee kub
# 962                       ดีคับ
# 963                  สวัสดีครับ
# 964                          Hi
# Name: img : Trichuris, Length: 965, dtype: object

# %%
text_M = ''
for i in range(len(df_4)):
        x = df_4.iloc[i,4]
        text_M += x

# %%
wordcloud = WordCloud(width=1280, height=853, margin=0,colormap='Blues').generate(text_M)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.margins(x=0, y=0)

# %% [markdown]
# #### Word Cloud ภาษาไทย

# %%
regexp = r"[ก-๙a-zA-Z']+" # กำหนดคำตัวอย่างคำภาษาไทยกับภาษาอังกฤษ

# %%
path = '/content/THSarabunNew.ttf' #ดาวน์โหลด Font ที่ต้องการใช้

# %%
wordcloud = WordCloud(
                      font_path=path, 
                      relative_scaling = 0.3,
                      min_font_size=1,
                      background_color="Gray",
                      width=1024,
                      height=768,
                      max_words=2000, 
                      colormap='seismic', 
                      scale=3,
                      font_step=4,
                      collocations=False,
                      regexp=regexp,
                      margin=2
                      ).generate(text_M)

fig, ax = plt.subplots(1, 1, figsize=(16, 12))
ax.imshow(wordcloud, interpolation='bilinear')
ax.axis("off")
fig.show()
# Out:
# C:\Users\User-12213\Miniconda3\lib\site-packages\ipykernel_launcher.py:20: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
