# %%
def createDict(input1,input2,input3):
    if input3 == True:
        d = {input1[0] : input2[0], input1[1] : input2[1]}
        print(d)
    elif  input3 == False:
        b = {input2[0] : input1[0], input2[1] : input1[1]}
        print(b)

# %%
output1 = createDict(['apple','banana'],[1,2],True)
# Out:
# {'apple': 1, 'banana': 2}

# %%
output2 = createDict(['apple','banana'],[1,2],False)
# Out:
# {1: 'apple', 2: 'banana'}

# %%
import random

# %%
print(random.random(10))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-9b58c35b8302> in <module>
# ----> 1 print(random.random(10))
#
# TypeError: random() takes no arguments (1 given)

# %%
def genPassword(ran1,ran2):
    for i in range(ran1):
        c = random.randint(0,9):
            
        print([c])

# %%
output = genPassword(8,3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-403cb6d58c31> in <module>
# ----> 1 output = genPassword(8,3)
#
# <ipython-input-16-77985a610756> in genPassword(ran1, ran2)
#       1 def genPassword(ran1,ran2):
#       2     for i in range(ran1):
# ----> 3         c = ran1(random.randint(0,9))
#       4         print([c])
#
# TypeError: 'int' object is not callable

# %%
def random_pass(length):
    pw = str()
    char = "abcdefghijklmnopqrstuvwxyz"
    numb = "0123456789"
    for i in range(length):
        pw = pw+random.choice(char)
    print([pw])

# %%
random_pass(10)
# Out:
# ['zyyf2pvpo7']

# %%
def random_pass(length):
    pw = str()
    charabcdefghijklmnopqrstuvwxyz"
    numb = "0123456789"
    for i in range(length):
        pw = pw+random.choice(char) +andom.choice(numb)
    print(pw)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
res = pd.read_csv('D:\\basicdata\Python_datavizz\search_click.csv')
res.head()
# Out:
#   click_timestamp                             search_id  business_id  \
# 0         11:38.9  5c004472-5ecc-4159-9698-9f329b8e26e1     298839.0
# 1         30:51.3  5f34eca0-c04e-4c10-b600-54aa447dbd8e     171372.0
# 2         32:09.6  8dc6d1f0-11f1-4239-9dd2-5c1674c81224      16157.0
# 3         00:59.8  1a5810e9-3d1f-44b9-9a2e-26ede21c524b      89741.0
# 4         23:36.8  6bc75e0d-fc65-471e-9926-ff6be6708639     189564.0
#
#    display_position  time_diff_nanos   ads
# 0                 0     2.222400e+15  True
# 1                 0     4.608380e+14  True
# 2                 0     2.581490e+15  True
# 3                 1     1.404580e+15  True
# 4                 1     9.333590e+14  True

# %%
res['aa'] = res['click_timestamp'].str.replace('\:', ' ')

# %%
res
# Out:
#         click_timestamp                             search_id  business_id  \
# 0               11:38.9  5c004472-5ecc-4159-9698-9f329b8e26e1     298839.0
# 1               30:51.3  5f34eca0-c04e-4c10-b600-54aa447dbd8e     171372.0
# 2               32:09.6  8dc6d1f0-11f1-4239-9dd2-5c1674c81224      16157.0
# 3               00:59.8  1a5810e9-3d1f-44b9-9a2e-26ede21c524b      89741.0
# 4               23:36.8  6bc75e0d-fc65-471e-9926-ff6be6708639     189564.0
# ...                 ...                                   ...          ...
# 1048570         05:28.8  99aab616-6fc5-4fbf-994b-4aebee7bb360     278479.0
# 1048571         15:28.8  d70a2c5d-ee94-4e4c-9f7c-c5faac6db12a     321885.0
# 1048572         11:49.4  4c1de7fe-300e-41aa-9d01-914344fc3753     221035.0
# 1048573         10:33.7  2ec0ddec-e450-4b98-9779-42b77aa7eda5     220572.0
# 1048574         13:51.4  5741d9cf-b9f1-441d-aa83-d2b0179bf874     310448.0
#
#          display_position  time_diff_nanos    ads       aa
# ...

# %%
res['aa'] = res['click_timestamp'].str.replace('\:.*', ' ')
